# %%
import pandas as pd

# %%
data = pd.read_csv('./data/open-beer-database.csv', error_bad_lines=False)
# Out:
# b'Skipping line 12: expected 2 fields, saw 3\nSkipping line 21: expected 2 fields, saw 3\nSkipping line 22: expected 2 fields, saw 14\nSkipping line 24: expected 2 fields, saw 8\nSkipping line 28: expected 2 fields, saw 7\nSkipping line 29: expected 2 fields, saw 5\nSkipping line 46: expected 2 fields, saw 6\nSkipping line 47: expected 2 fields, saw 6\nSkipping line 49: expected 2 fields, saw 3\nSkipping line 50: expected 2 fields, saw 3\nSkipping line 53: expected 2 fields, saw 3\nSkipping line 55: expected 2 fields, saw 3\nSkipping line 61: expected 2 fields, saw 4\nSkipping line 63: expected 2 fields, saw 5\nSkipping line 64: expected 2 fields, saw 4\nSkipping line 65: expected 2 fields, saw 4\nSkipping line 68: expected 2 fields, saw 8\nSkipping line 69: expected 2 fields, saw 5\nSkipping line 74: expected 2 fields, saw 3\nSkipping line 78: expected 2 fields, saw 4\nSkipping line 79: expected 2 fields, saw 3\nSkipping line 82: expected 2 fields, saw 3\nSkipping line 98: expected 
# ...

# %%
data.shape
# Out:
# (5018, 1)

# %%
data.head()
# Out:
#                                                    Name;id;brewery_id;cat_id;style_id;Alcohol By Volume;International Bitterness Units;Standard Reference Method;Universal Product Code;filepath;Description;add_user;last_mod;Style;Category;Brewer;Address;City;State;Country;Coordinates;Website
# Porter;716;842;2;25;0.0;0;0;0;;;0;2010-07-22T16...                                          -122.211;
# Possession Porter;723;445;2;25;5.5999999046;0;0...               -122.305;http://www.diamondknot.com/
# Maibock;736;1124;7;90;0.0;0;0;0;;;0;2010-07-22T...                                          -122.214;
# Free Bike Amber;742;1151;3;33;4.5;0;0;0;;;0;201...                                          -122.335;
# Oatmeal Stout;961;691;3;42;0.0;0;0;0;;;0;2010-0...       -75.1594;http://www.independencebrewpub.com/
